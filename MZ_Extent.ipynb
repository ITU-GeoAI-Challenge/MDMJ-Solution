# %%
import os
import glob
import sklearn
import pandas as pd
import numpy as np
import gdal
from google.colab import drive
from google.colab import auth
from sklearn.model_selection import train_test_split
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.ensemble import RandomForestClassifier
auth.authenticate_user()
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **1. Reading geotiff file and samples**

# %%
#function to read geotiff
def readtiff(filename):
    # @ file name to read
    file = gdal.Open(filename, gdal.GA_ReadOnly)
    band_number = file.RasterCount
    #print(band_number)
    #data = file.GetRasterBand(0,23)
    #print(data)
    array = file.ReadAsArray()
    return array

# %%
#read RS data
RS_file = '/content/drive/MyDrive/Senior Design/Competition /Dataset/Competition_Dataset/MZ/MZ_NDVI.tif'
array_NDVI = readtiff(RS_file)
array_shape = array_NDVI.shape
array_result = np.zeros((array_shape[1],array_shape[2]),dtype=int)
file_geo = gdal.Open(RS_file, gdal.GA_ReadOnly)

# %%
df_crop = pd.read_csv('/content/drive/MyDrive/Senior Design/Competition /Samples/MZ_samples/MZ_cropland.csv', sep=',', header=None)
df_crop = df_crop.drop([0, 25], axis=1)
new_header = df_crop.iloc[0]
df_crop = df_crop[1:] 
df_crop.columns = new_header
df_noncrop = pd.read_csv('/content/drive/MyDrive/Senior Design/Competition /Samples/MZ_samples/MZ_noncropland.csv', sep=',', header=None)
df_noncrop = df_noncrop.drop([0, 25], axis=1)
new_header = df_noncrop.iloc[0]
df_noncrop = df_noncrop[1:] 
df_noncrop.columns = new_header

# %% [markdown]
# # **2. Pre-processing and NDVI reconstruction**

# %%
from scipy.signal import savgol_filter
def ndvi_reconstruct(df):
  for i in range(len(df)):
    smoothed_NDVI = savgol_filter(df.iloc[i], window_length = 3, polyorder = 2)
    df.iloc[i] = smoothed_NDVI
    for j in range(len(df.columns)-1):
       if df.iat[i,j] == 0 or  abs(df.iat[i,j-1] - df.iat[i,j]) > 4000 :
              df.iat[i,j] = ((df.iloc[i][1]+df.iloc[i][len(df.columns)-1])/2.0)
       if j == len(df.columns)-1:
                df.iat[i,j] = ((df.iloc[i][j-1]+df.iloc[i][0])/2.0)
       if j != 0 and j != len(df.columns) - 1:
                df.iat[i,j] = ((df.iloc[i][j-1]+df.iloc[i][j+1])/2.0)
  return df

# %%
from sklearn import preprocessing
def normalize(df):
  scaler = preprocessing.MinMaxScaler(feature_range=(-1, 1))
  names = df.columns
  d = scaler.fit_transform(df)
  scaled_df = pd.DataFrame(d, columns=names)
  return scaled_df

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot
series = df_crop.astype(float).iloc[1]
series.plot()
plt.title("NDVI Time series of point 1")
plt.xlabel("image")
plt.ylabel("NDVI score")
plt.ylim([0, 9000])
plt.xlim([0, 24])
pyplot.show()
df_crop = df_crop.astype(float)
df_crop = ndvi_reconstruct(df_crop)
series = df_crop.iloc[1]
series.plot()
plt.title("NDVI Time series of point 1")
plt.xlabel("image")
plt.ylabel("NDVI score")
plt.ylim([0, 9000])
plt.xlim([0, 24])
pyplot.show()

series = df_noncrop.astype(float).iloc[20]
series.plot()
plt.title("NDVI Time series of point 20")
plt.xlabel("image")
plt.ylabel("NDVI score")
plt.ylim([-2000, 9000])
plt.xlim([0, 24])
pyplot.show()
df_noncrop = df_noncrop.astype(float)
df_noncrop = ndvi_reconstruct(df_noncrop)
series = df_noncrop.iloc[1]
series.plot()
plt.title("NDVI Time series of point 20")
plt.xlabel("image")
plt.ylabel("NDVI score")
plt.ylim([-2000, 9000])
plt.xlim([0, 24])
pyplot.show()

# %%
df_crop = ndvi_reconstruct(df_crop.astype(float))
#df_crop = normalize(df_crop)
df_crop['class'] = 1
df_noncrop = ndvi_reconstruct(df_noncrop.astype(float))
#df_noncrop = normalize(df_noncrop)
df_noncrop['class'] = 0
df = pd.concat([df_crop, df_noncrop])
df = df.sample(frac = 1).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics 
x=df.drop(["class"], axis = 1);
y=df["class"]
x_train=[]
y_train=[]
x_test=[]
y_test=[]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, shuffle=True )
x_train=np.array(x_train).astype('int').reshape(100,24)
y_train=np.array(y_train).astype('int').reshape(100)
x_test=np.array(x_test).astype('int').reshape(50,24)
y_test=np.array(y_test).astype('int').reshape(50)

# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(100).fit(x_train, y_train)
expected_y  = y_test
predicted_y = rf.predict(x_test)
print(metrics.classification_report(expected_y, predicted_y))
print(metrics.confusion_matrix(expected_y, predicted_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.69      0.71        26
#            1       0.68      0.71      0.69        24
#
#     accuracy                           0.70        50
#    macro avg       0.70      0.70      0.70        50
# weighted avg       0.70      0.70      0.70        50
#
# [[18  8]
#  [ 7 17]]

# %%
pip install geemap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: geemap in /usr/local/lib/python3.7/dist-packages (0.17.1)
# Requirement already satisfied: ee-extra>=0.0.10 in /usr/local/lib/python3.7/dist-packages (from geemap) (0.0.14)
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (from geemap) (4.4.0)
# Requirement already satisfied: sankee>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from geemap) (0.2.0)
# Requirement already satisfied: whiteboxgui>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from geemap) (0.7.0)
# Requirement already satisfied: geeadd>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from geemap) (0.5.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from geemap) (1.3.5)
# Requirement already satisfied: geocoder in /usr/local/lib/python3.7/dist-packages (from geemap) (1.38.1)
# Requirement already satisfied: scooby in /usr/local/lib/python3.7/dist-packages (from geemap) (0.6.0)
# Requirement already satisfied: pycrs in /usr/local/lib/python3.7/dist-packages (from geemap) (1.0.2)
# Requirement already satisfied: jupyterlab>=3 in /usr/local/lib/python3.7/dist-packages (from geemap) (3.4.8)
# Requirement already satisfied: ipyleaflet>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from geemap) (0.17.1)
# Requirement already satisfied: python-box in /usr/local/lib/python3.7/dist-packages (from geemap) (6.0.2)
# Requirement already satisfied: pyshp>=2.1.3 in /usr/local/lib/python3.7/dist-packages (from geemap) (2.3.1)
# Requirement already satisfied: folium>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from geemap) (0.12.1.post1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from geemap) (1.21.6)
# Requirement already satisfied: earthengine-api>=0.1.304 in /usr/local/lib/python3.7/dist-packages (from geemap) (0.1.326)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from geemap) (3.2.2)
# Requirement already satisfied: ipytree in /usr/local/lib/python3.7/dist-packages (from geemap) (0.2.2)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.7/dist-packages (from geemap) (2.0.1)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.7/dist-packages (from geemap) (0.12.36)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from geemap) (7.1.2)
# Requirement already satisfied: colour in /usr/local/lib/python3.7/dist-packages (from geemap) (0.1.5)
# Requirement already satisfied: geojson in /usr/local/lib/python3.7/dist-packages (from geemap) (2.5.0)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.7/dist-packages (from geemap) (2022.9.0)
# Requirement already satisfied: ffmpeg-python in /usr/local/lib/python3.7/dist-packages (from geemap) (0.2.0)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from geemap) (0.6.0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.7/dist-packages (from earthengine-api>=0.1.304->geemap) (1.18.1)
# Requirement already satisfied: httplib2shim in /usr/local/lib/python3.7/dist-packages (from earthengine-api>=0.1.304->geemap) (0.0.3)
# Requirement already satisfied: google-api-python-client<2,>=1.12.1 in /usr/local/lib/python3.7/dist-packages (from earthengine-api>=0.1.304->geemap) (1.12.11)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from earthengine-api>=0.1.304->geemap) (1.15.0)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from earthengine-api>=0.1.304->geemap) (1.35.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from earthengine-api>=0.1.304->geemap) (0.16.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from earthengine-api>=0.1.304->geemap) (0.0.4)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from earthengine-api>=0.1.304->geemap) (0.17.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from folium>=0.11.0->geemap) (2.23.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from folium>=0.11.0->geemap) (3.1.2)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from folium>=0.11.0->geemap) (0.5.0)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from geeadd>=0.5.1->geemap) (4.11.1)
# Requirement already satisfied: logzero>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from geeadd>=0.5.1->geemap) (1.7.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.7/dist-packages (from beautifulsoup4>=4.9.0->geeadd>=0.5.1->geemap) (2.3.2.post1)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (3.0.1)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (1.31.6)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (2022.4)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (1.56.4)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (57.4.0)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (3.17.3)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (21.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (4.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (0.2.8)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.7/dist-packages (from ipyfilechooser>=0.6.0->geemap) (7.7.1)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from ipyleaflet>=0.17.0->geemap) (0.2.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.3.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.3)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.6.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.4.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.9.0)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.1.12)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.6.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.10)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.9->folium>=0.11.0->geemap) (2.0.1)
# Requirement already satisfied: tomli in /usr/local/lib/python3.7/dist-packages (from jupyterlab>=3->geemap) (2.0.1)
# Requirement already satisfied: jupyterlab-server~=2.10 in /usr/local/lib/python3.7/dist-packages (from jupyterlab>=3->geemap) (2.16.0)
# Requirement already satisfied: jupyter-server~=1.16 in /usr/local/lib/python3.7/dist-packages (from jupyterlab>=3->geemap) (1.21.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from jupyterlab>=3->geemap) (4.11.1)
# Requirement already satisfied: notebook<7 in /usr/local/lib/python3.7/dist-packages (from jupyterlab>=3->geemap) (5.5.0)
# Requirement already satisfied: nbclassic in /usr/local/lib/python3.7/dist-packages (from jupyterlab>=3->geemap) (0.4.6)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (1.4.1)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (7.2.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (0.15.0)
# Requirement already satisfied: nbformat>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (5.7.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (21.3.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (23.2.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (1.8.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (3.6.1)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (0.13.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab>=3->geemap) (4.1.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.7/dist-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab>=3->geemap) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.7/dist-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab>=3->geemap) (2.10)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.8.2)
# Requirement already satisfied: json5 in /usr/local/lib/python3.7/dist-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (0.9.10)
# Requirement already satisfied: babel in /usr/local/lib/python3.7/dist-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (2.10.3)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /usr/local/lib/python3.7/dist-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (5.0.0)
# Requirement already satisfied: jsonschema>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (4.3.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.3->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (3.9.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (5.10.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (0.18.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (5.0.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.7.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.2.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (1.1.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (2.0.4)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.7/dist-packages (from nbclient>=0.5.0->nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (1.5.6)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat>=5.2.0->jupyter-server~=1.16->jupyterlab>=3->geemap) (2.16.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (3.0.9)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->folium>=0.11.0->geemap) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->folium>=0.11.0->geemap) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->folium>=0.11.0->geemap) (3.0.4)
# Requirement already satisfied: plotly>=5.2.2 in /usr/local/lib/python3.7/dist-packages (from sankee>=0.1.0->geemap) (5.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=5.2.2->sankee>=0.1.0->geemap) (8.1.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.3->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.7.0)
# Requirement already satisfied: whitebox in /usr/local/lib/python3.7/dist-packages (from whiteboxgui>=0.6.0->geemap) (2.1.4)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.7/dist-packages (from argon2-cffi->jupyter-server~=1.16->jupyterlab>=3->geemap) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab>=3->geemap) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab>=3->geemap) (2.21)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.5.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown->geemap) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown->geemap) (3.8.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from geocoder->geemap) (7.1.2)
# Requirement already satisfied: ratelim in /usr/local/lib/python3.7/dist-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage->earthengine-api>=0.1.304->geemap) (1.0.3)
# Requirement already satisfied: google-resumable-media<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage->earthengine-api>=0.1.304->geemap) (0.4.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->geemap) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->geemap) (0.11.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from nbclassic->jupyterlab>=3->geemap) (0.1.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests->folium>=0.11.0->geemap) (1.7.1)

# %%
import geemap
import ee
from geemap import ml
geemap.ee_initialize()

bands = ['nd_p100','nd_p100_1','nd_p100_2','nd_p100_3','nd_p100_4','nd_p100_5','nd_p100_6','nd_p100_7','nd_p100_8','nd_p100_9','nd_p100_10','nd_p100_11','nd_p100_12','nd_p100_13','nd_p100_14','nd_p100_15','nd_p100_16','nd_p100_17','nd_p100_18','nd_p100_19','nd_p100_20','nd_p100_21','nd_p100_22','nd_p100_23']
label = "class"

image = ee.Image('projects/ee-g00085636/assets/NDVI_MZ_unmasked') #IRAN

# %%
trees = ml.rf_to_strings(rf, bands)
ee_classifier = ml.strings_to_classifier(trees)
classified = image.select(bands).classify(ee_classifier)
Map = geemap.Map(center=(48.08,32.5),zoom=10)

Map.addLayer(
    image,
    {"bands": ['nd_p100_2','nd_p100_5','nd_p100_7'], "min": -10000, "max": 10000, "gamma": 1.5},
    'image',
)
Map.addLayer(
    classified,
    { "palette": ['#444444', '#e49635']},
    'classification',
)
Map
# Out:
# Map(center=[48.08, 32.5], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children…

# %%
df_crop = pd.read_csv('/content/drive/MyDrive/Senior Design/Competition /Samples/MZ_samples/MZ_cropland.csv', sep=',', header=None)
df_crop = df_crop.drop([0, 25], axis=1)
new_header = df_crop.iloc[0]
df_crop = df_crop[1:] 
df_crop.columns = new_header
df_noncrop = pd.read_csv('/content/drive/MyDrive/Senior Design/Competition /Samples/MZ_samples/MZ_noncropland.csv', sep=',', header=None)
df_noncrop = df_noncrop.drop([0, 25], axis=1)
new_header = df_noncrop.iloc[0]
df_noncrop = df_noncrop[1:] 
df_noncrop.columns = new_header

# %%
df_crop = ndvi_reconstruct(df_crop.astype(float))
df_crop = normalize(df_crop)
df_crop['class'] = 1
df_noncrop = ndvi_reconstruct(df_noncrop.astype(float))
df_noncrop = normalize(df_noncrop)
df_noncrop['class'] = 0
df = pd.concat([df_crop, df_noncrop])
df = df.sample(frac = 1).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics 
x=df.drop(["class"], axis = 1);
y=df["class"]
x_train=[]
y_train=[]
x_test=[]
y_test=[]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, shuffle=True )
x_train=np.array(x_train).astype('float').reshape(100,24)
y_train=np.array(y_train).astype('float').reshape(100)
x_test=np.array(x_test).astype('float').reshape(50,24)
y_test=np.array(y_test).astype('float').reshape(50)

# %%
x_train_lstm = x_train.reshape((x_train.shape[0],x_train.shape[1],1))
x_test_lstm = x_test.reshape((x_test.shape[0],x_test.shape[1],1))

# %%
from keras.metrics.metrics import accuracy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

n_steps = 24
n_features = 1 
# define model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse',metrics=['accuracy'],)

# %%
hist = model.fit(x_train_lstm, y_train, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 2s 12ms/step - loss: 0.5411 - accuracy: 0.4600
# Epoch 2/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4985 - accuracy: 0.4600
# Epoch 3/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4546 - accuracy: 0.4600
# Epoch 4/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4027 - accuracy: 0.4600
# Epoch 5/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3431 - accuracy: 0.4600
# Epoch 6/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2848 - accuracy: 0.4400
# Epoch 7/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2739 - accuracy: 0.6000
# Epoch 8/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2892 - accuracy: 0.5600
# Epoch 9/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2512 - accuracy: 0.6300
# Epoch 10/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2444 - accuracy: 0.6000
# Epoch 11/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2420 - accuracy: 0.6200
# Epoch 12/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2382 - accuracy: 0.6700
# Epoch 13/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2374 - accuracy: 0.6900
# Epoch 14/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2369 - accuracy: 0.6700
# Epoch 15/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2368 - accuracy: 0.6900
# Epoch 16/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2307 - accuracy: 0.7200
# Epoch 17/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2273 - accuracy: 0.7200
# Epoch 18/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2237 - accuracy: 0.7400
# Epoch 19/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2230 - accuracy: 0.6900
# Epoch 20/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2226 - accuracy: 0.6600
# Epoch 21/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2148 - accuracy: 0.6700
# Epoch 22/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2209 - accuracy: 0.7100
# Epoch 23/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2213 - accuracy: 0.6800
# Epoch 24/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2090 - accuracy: 0.7200
# Epoch 25/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2085 - accuracy: 0.7700
# Epoch 26/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2064 - accuracy: 0.7200
# Epoch 27/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2015 - accuracy: 0.7300
# Epoch 28/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2001 - accuracy: 0.7400
# Epoch 29/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1992 - accuracy: 0.7900
# Epoch 30/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1911 - accuracy: 0.7400
# Epoch 31/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2082 - accuracy: 0.6900
# Epoch 32/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1861 - accuracy: 0.7600
# Epoch 33/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1987 - accuracy: 0.7500
# Epoch 34/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1972 - accuracy: 0.6900
# Epoch 35/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1866 - accuracy: 0.7100
# Epoch 36/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1791 - accuracy: 0.7200
# Epoch 37/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1738 - accuracy: 0.7200
# Epoch 38/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1659 - accuracy: 0.7400
# Epoch 39/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1636 - accuracy: 0.7600
# Epoch 40/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1648 - accuracy: 0.8100
# Epoch 41/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1564 - accuracy: 0.8100
# Epoch 42/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1628 - accuracy: 0.7600
# Epoch 43/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1473 - accuracy: 0.8200
# Epoch 44/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1493 - accuracy: 0.8100
# Epoch 45/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1470 - accuracy: 0.8200
# Epoch 46/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1639 - accuracy: 0.7400
# Epoch 47/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1446 - accuracy: 0.8200
# Epoch 48/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1471 - accuracy: 0.8500
# Epoch 49/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1426 - accuracy: 0.8400
# Epoch 50/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1395 - accuracy: 0.8200
# Epoch 51/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1367 - accuracy: 0.8300
# Epoch 52/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1398 - accuracy: 0.8100
# Epoch 53/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1459 - accuracy: 0.8300
# Epoch 54/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1418 - accuracy: 0.8100
# Epoch 55/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1445 - accuracy: 0.8200
# Epoch 56/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1368 - accuracy: 0.8500
# Epoch 57/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1467 - accuracy: 0.8300
# Epoch 58/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1432 - accuracy: 0.8300
# Epoch 59/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1350 - accuracy: 0.8600
# Epoch 60/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1354 - accuracy: 0.8200
# Epoch 61/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1373 - accuracy: 0.8200
# Epoch 62/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1468 - accuracy: 0.8200
# Epoch 63/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1372 - accuracy: 0.8200
# Epoch 64/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1333 - accuracy: 0.8300
# Epoch 65/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1330 - accuracy: 0.8400
# Epoch 66/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1304 - accuracy: 0.8500
# Epoch 67/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1299 - accuracy: 0.8400
# Epoch 68/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1302 - accuracy: 0.8500
# Epoch 69/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1297 - accuracy: 0.8500
# Epoch 70/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1293 - accuracy: 0.8200
# Epoch 71/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1285 - accuracy: 0.8200
# Epoch 72/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1319 - accuracy: 0.8200
# Epoch 73/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1422 - accuracy: 0.8000
# Epoch 74/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1657 - accuracy: 0.7500
# Epoch 75/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1488 - accuracy: 0.8100
# Epoch 76/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1367 - accuracy: 0.8200
# Epoch 77/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1322 - accuracy: 0.8300
# Epoch 78/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1368 - accuracy: 0.8000
# Epoch 79/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1409 - accuracy: 0.8100
# Epoch 80/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1290 - accuracy: 0.8300
# Epoch 81/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1365 - accuracy: 0.8000
# Epoch 82/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1271 - accuracy: 0.8300
# Epoch 83/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1263 - accuracy: 0.8500
# Epoch 84/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1385 - accuracy: 0.8200
# Epoch 85/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1283 - accuracy: 0.8400
# Epoch 86/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1341 - accuracy: 0.8700
# Epoch 87/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1367 - accuracy: 0.8500
# Epoch 88/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1247 - accuracy: 0.8400
# Epoch 89/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1303 - accuracy: 0.8300
# Epoch 90/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1279 - accuracy: 0.8500
# Epoch 91/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1275 - accuracy: 0.8300
# Epoch 92/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1291 - accuracy: 0.8500
# Epoch 93/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1269 - accuracy: 0.8400
# Epoch 94/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1309 - accuracy: 0.8400
# Epoch 95/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1220 - accuracy: 0.8600
# Epoch 96/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1225 - accuracy: 0.8300
# Epoch 97/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1230 - accuracy: 0.8200
# Epoch 98/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1217 - accuracy: 0.8500
# Epoch 99/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1211 - accuracy: 0.8400
# Epoch 100/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1207 - accuracy: 0.8400

# %%
plt.plot(hist.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(hist.history['loss']) 
plt.title('Model loss') 
plt.ylabel('Loss') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Validation'], loc='upper right') 
plt.show()

# %%
# from sklearn.metrics import classification_report, confusion_matrix
# expected_y  = y_test
# predicted_y = model.predict(x_test_lstm, verbose=0)
scores = model.evaluate(x_test_lstm, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Accuracy: 82.00%

# %%
import xgboost as xgb

model = xgb.XGBClassifier()
model.fit(x_train, y_train)
expected_y  = y_test
predicted_y = model.predict(x_test)
print(metrics.classification_report(expected_y, predicted_y))
print(metrics.confusion_matrix(expected_y, predicted_y))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.81      0.82        26
#          1.0       0.80      0.83      0.82        24
#
#     accuracy                           0.82        50
#    macro avg       0.82      0.82      0.82        50
# weighted avg       0.82      0.82      0.82        50
#
# [[21  5]
#  [ 4 20]]

# %%
from keras.layers import Bidirectional, Activation

model = Sequential()
model.add(Bidirectional(LSTM(50, return_sequences=True),
                             input_shape=(24, 1)))
model.add(Bidirectional(LSTM(50)))
model.add(Dense(1))
model.add(Activation('sigmoid'))
model.compile(loss='mse',
optimizer='adam',
metrics=['accuracy'])

# %%
hist = model.fit(x_train_lstm, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 7s 36ms/step - loss: 0.2491 - accuracy: 0.5100
# Epoch 2/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.2400 - accuracy: 0.6200
# Epoch 3/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2341 - accuracy: 0.5900
# Epoch 4/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2301 - accuracy: 0.6200
# Epoch 5/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2297 - accuracy: 0.6100
# Epoch 6/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2284 - accuracy: 0.6000
# Epoch 7/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2243 - accuracy: 0.6000
# Epoch 8/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2216 - accuracy: 0.6000
# Epoch 9/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.2187 - accuracy: 0.6200
# Epoch 10/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2164 - accuracy: 0.6200
# Epoch 11/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2158 - accuracy: 0.6300
# Epoch 12/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2150 - accuracy: 0.6100
# Epoch 13/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2217 - accuracy: 0.6200
# Epoch 14/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2142 - accuracy: 0.6300
# Epoch 15/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2217 - accuracy: 0.6400
# Epoch 16/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2115 - accuracy: 0.6700
# Epoch 17/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2175 - accuracy: 0.6300
# Epoch 18/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2242 - accuracy: 0.6300
# Epoch 19/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2186 - accuracy: 0.6300
# Epoch 20/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.2104 - accuracy: 0.6500
# Epoch 21/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2152 - accuracy: 0.6400
# Epoch 22/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2158 - accuracy: 0.6400
# Epoch 23/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2123 - accuracy: 0.6600
# Epoch 24/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2091 - accuracy: 0.6500
# Epoch 25/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2073 - accuracy: 0.6500
# Epoch 26/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.2068 - accuracy: 0.6300
# Epoch 27/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2050 - accuracy: 0.6100
# Epoch 28/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2047 - accuracy: 0.6200
# Epoch 29/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2064 - accuracy: 0.6300
# Epoch 30/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2080 - accuracy: 0.6400
# Epoch 31/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2095 - accuracy: 0.6400
# Epoch 32/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2088 - accuracy: 0.6300
# Epoch 33/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2034 - accuracy: 0.6200
# Epoch 34/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1938 - accuracy: 0.6800
# Epoch 35/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2037 - accuracy: 0.6800
# Epoch 36/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1998 - accuracy: 0.7200
# Epoch 37/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1978 - accuracy: 0.6500
# Epoch 38/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1992 - accuracy: 0.6300
# Epoch 39/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1972 - accuracy: 0.6200
# Epoch 40/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1945 - accuracy: 0.6700
# Epoch 41/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.1923 - accuracy: 0.7000
# Epoch 42/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1907 - accuracy: 0.7500
# Epoch 43/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1867 - accuracy: 0.7300
# Epoch 44/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1843 - accuracy: 0.6800
# Epoch 45/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1828 - accuracy: 0.7100
# Epoch 46/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1822 - accuracy: 0.6900
# Epoch 47/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.1772 - accuracy: 0.6900
# Epoch 48/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.1789 - accuracy: 0.7200
# Epoch 49/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.1774 - accuracy: 0.7500
# Epoch 50/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1775 - accuracy: 0.7600
# Epoch 51/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1780 - accuracy: 0.7300
# Epoch 52/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1761 - accuracy: 0.7400
# Epoch 53/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1752 - accuracy: 0.7600
# Epoch 54/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1752 - accuracy: 0.7500
# Epoch 55/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1775 - accuracy: 0.7000
# Epoch 56/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1697 - accuracy: 0.7500
# Epoch 57/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1671 - accuracy: 0.7700
# Epoch 58/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1678 - accuracy: 0.7500
# Epoch 59/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1704 - accuracy: 0.7500
# Epoch 60/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1660 - accuracy: 0.7800
# Epoch 61/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1645 - accuracy: 0.7500
# Epoch 62/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1674 - accuracy: 0.7700
# Epoch 63/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1683 - accuracy: 0.7300
# Epoch 64/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1786 - accuracy: 0.6800
# Epoch 65/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1657 - accuracy: 0.7500
# Epoch 66/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.1554 - accuracy: 0.7300
# Epoch 67/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1582 - accuracy: 0.7700
# Epoch 68/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1565 - accuracy: 0.7800
# Epoch 69/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1516 - accuracy: 0.7600
# Epoch 70/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.1626 - accuracy: 0.7600
# Epoch 71/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1592 - accuracy: 0.7700
# Epoch 72/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1458 - accuracy: 0.7600
# Epoch 73/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1494 - accuracy: 0.7500
# Epoch 74/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1430 - accuracy: 0.8100
# Epoch 75/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1455 - accuracy: 0.7500
# Epoch 76/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1589 - accuracy: 0.7500
# Epoch 77/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1394 - accuracy: 0.7400
# Epoch 78/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1443 - accuracy: 0.7700
# Epoch 79/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.1440 - accuracy: 0.8000
# Epoch 80/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1386 - accuracy: 0.7800
# Epoch 81/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1311 - accuracy: 0.8300
# Epoch 82/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1432 - accuracy: 0.7400
# Epoch 83/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1262 - accuracy: 0.8000
# Epoch 84/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1437 - accuracy: 0.8200
# Epoch 85/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1423 - accuracy: 0.8000
# Epoch 86/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1241 - accuracy: 0.8200
# Epoch 87/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1247 - accuracy: 0.8100
# Epoch 88/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.1214 - accuracy: 0.8100
# Epoch 89/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1176 - accuracy: 0.8400
# Epoch 90/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1099 - accuracy: 0.8600
# Epoch 91/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1034 - accuracy: 0.8600
# Epoch 92/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1009 - accuracy: 0.8800
# Epoch 93/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1000 - accuracy: 0.8600
# Epoch 94/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0973 - accuracy: 0.8600
# Epoch 95/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0974 - accuracy: 0.8400
# Epoch 96/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1283 - accuracy: 0.8200
# Epoch 97/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1120 - accuracy: 0.8300
# Epoch 98/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1056 - accuracy: 0.8400
# Epoch 99/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.1252 - accuracy: 0.8000
# Epoch 100/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1167 - accuracy: 0.8400

# %%
scores = model.evaluate(x_test_lstm, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Accuracy: 80.00%

# %%
# LSTM EXPORTING
# for i in range(array_shape[1]):
#   #get the data for a line
#   temp_array = array_NDVI[:,i,:]
#   temp_df = pd.DataFrame(temp_array.T)
#   temp_df.columns = pd.DataFrame(x_train).columns.tolist()
#   temp_df_test = temp_df.to_numpy()
#   temp_df_test = temp_df_test.reshape((temp_df_test.shape[0],temp_df_test.shape[1],1))
#   predections = model.predict(temp_df_test)


#RandomForest EXPORTING

for i in range(array_shape[1]):
  #get the data for a line
  temp_array = array_NDVI[:,i,:]
  temp_df = pd.DataFrame(temp_array.T)
  temp_df.columns = pd.DataFrame(x_train).columns.tolist() #unnormalized_x_train (CAUTIONS) 
  array_result[i,:] = rf.predict(temp_df)

# %%
Output_file = '/content/drive/MyDrive/results/Cropland_extent_MZ_smooth.tif' #change
driver = gdal.GetDriverByName('Gtiff')
outRaster = driver.Create(Output_file, file_geo.RasterXSize, file_geo.RasterYSize, 1, gdal.GDT_Byte)
outRaster.SetGeoTransform(file_geo.GetGeoTransform())
outRaster.SetProjection(file_geo.GetProjection())
outRaster.GetRasterBand(1).WriteArray(array_result)
outRaster = None
